# %%
import numpy as np 
import pandas as pd
import pickle

# %%
df = pd.read_csv('/Users/home/Documents/GitHub/FormulaAIHacks/weather.csv',low_memory=False)

# %%
df
# Out:
#          M_PACKET_FORMAT  M_GAME_MAJOR_VERSION  M_GAME_MINOR_VERSION  \
# 0                   2021                     1                    14
# 1                   2021                     1                    14
# 2                   2021                     1                    14
# 3                   2021                     1                    14
# 4                   2021                     1                    14
# ...                  ...                   ...                   ...
# 3572323             2021                     1                    14
# 3572324             2021                     1                    14
# 3572325             2021                     1                    14
# 3572326             2021                     1                    14
# 3572327             2021                     1                    14
#
#          M_PACKET_VERSION  M_PACKET_ID         M_SESSION_UID  M_SESSION_TIME  \
# 0                       1            1  13002103581294142936        2803.836
# 1                       1            1  13002103581294142936        2803.836
# 2                       1            1  13002103581294142936        2803.836
# 3                       1            1  13002103581294142936        2803.836
# 4                       1            1  13002103581294142936        2803.836
# ...                   ...          ...                   ...             ...
# 3572323                 1            1  10862815468833217499         683.047
# 3572324                 1            1  10862815468833217499         683.047
# 3572325                 1            1  10862815468833217499         683.047
# 3572326                 1            1  10862815468833217499         683.047
# 3572327                 1            1  10862815468833217499         683.047
#
#          M_FRAME_IDENTIFIER  M_PLAYER_CAR_INDEX  M_SECONDARY_PLAYER_CAR_INDEX  \
# 0                     82458                   0                           255
# 1                     82458                   0                           255
# 2                     82458                   0                           255
# 3                     82458                   0                           255
# 4                     82458                   0                           255
# ...                     ...                 ...                           ...
# 3572323               22874                   1                           255
# 3572324               22874                   1                           255
# 3572325               22874                   1                           255
# 3572326               22874                   1                           255
# 3572327               22874                   1                           255
#
#          ...  M_AI_DIFFICULTY  M_PIT_SPEED_LIMIT  M_NETWORK_GAME  \
# 0        ...                0                 80             0.0
# 1        ...                0                 80             0.0
# 2        ...                0                 80             0.0
# 3        ...                0                 80             0.0
# 4        ...                0                 80             0.0
# ...      ...              ...                ...             ...
# 3572323  ...              110                 80             1.0
# 3572324  ...              110                 80             1.0
# 3572325  ...              110                 80             1.0
# 3572326  ...              110                 80             1.0
# 3572327  ...              110                 80             NaN
#
#          M_TOTAL_LAPS  M_STEERING_ASSIST  M_IS_SPECTATING  \
# 0               200.0                0.0              0.0
# 1               200.0                0.0              0.0
# 2               200.0                0.0              0.0
# 3               200.0                0.0              0.0
# 4               200.0                0.0              0.0
# ...               ...                ...              ...
# 3572323         200.0                0.0              0.0
# 3572324         200.0                0.0              0.0
# 3572325         200.0                0.0              0.0
# 3572326         200.0                0.0              0.0
# 3572327           NaN                NaN              NaN
#
#          M_DYNAMIC_RACING_LINE  M_DRSASSIST  M_NUM_MARSHAL_ZONES  Unnamed: 58
# 0                          0.0          0.0                 16.0          NaN
# 1                          0.0          0.0                 16.0          NaN
# 2                          0.0          0.0                 16.0          NaN
# 3                          0.0          0.0                 16.0          NaN
# 4                          0.0          0.0                 16.0          NaN
# ...                        ...          ...                  ...          ...
# 3572323                    0.0          0.0                 16.0          NaN
# 3572324                    0.0          0.0                 16.0          NaN
# 3572325                    0.0          0.0                 16.0          NaN
# 3572326                    0.0          0.0                 16.0          NaN
# 3572327                    NaN          NaN                  NaN          NaN
#
# [3572328 rows x 59 columns]

# %%
df = df[(df['M_NUM_WEATHER_FORECAST_SAMPLES'] != 0) & (df['M_WEATHER_FORECAST_SAMPLES_M_SESSION_TYPE'] != 0)]

# %%
df = df.drop([
    'M_PACKET_FORMAT', 
    'M_GAME_MAJOR_VERSION',  
    'M_GAME_MINOR_VERSION',  
    'M_PACKET_VERSION', 
    'M_PACKET_ID', 
    'M_SECONDARY_PLAYER_CAR_INDEX',
    'M_SLI_PRO_NATIVE_SUPPORT', 
    'Unnamed: 58',
    'GAMEHOST',
    'M_SESSION_UID',
    'M_SESSION_TIME',
    'M_FRAME_IDENTIFIER',
], axis=1)

# %%
pd.to_datetime(df['TIMESTAMP'], unit='s')
# Out:
# 17017     2022-01-21 00:16:50
# 17018     2022-01-21 00:16:50
# 17019     2022-01-21 00:16:50
# 17020     2022-01-21 00:16:50
# 17021     2022-01-21 00:16:50
#                   ...
# 3572287   2022-01-15 23:14:51
# 3572288   2022-01-15 23:14:51
# 3572289   2022-01-15 23:14:51
# 3572290   2022-01-15 23:14:51
# 3572291   2022-01-15 23:14:51
# Name: TIMESTAMP, Length: 1393074, dtype: datetime64[ns]

# %%
df_subset = df[['TIMESTAMP', 'M_AIR_TEMPERATURE','M_TIME_OFFSET'] + df.columns.tolist()[31:39]]
'rows with na:', df_subset.shape[0] - df_subset.dropna().shape[0]
# Out:
# ('rows with na:', 748671)

# %%
df_subset
# Out:
#             TIMESTAMP  M_AIR_TEMPERATURE  M_TIME_OFFSET  \
# 17017    1.642724e+09                 25            NaN
# 17018    1.642724e+09                 25            NaN
# 17019    1.642724e+09                 25            NaN
# 17020    1.642724e+09                 25            NaN
# 17021    1.642724e+09                 25            NaN
# ...               ...                ...            ...
# 3572287  1.642288e+09                 25           10.0
# 3572288  1.642288e+09                 25           15.0
# 3572289  1.642288e+09                 25           30.0
# 3572290  1.642288e+09                 25           45.0
# 3572291  1.642288e+09                 25           60.0
#
#          M_WEATHER_FORECAST_SAMPLES_M_WEATHER  \
# 17017                                     NaN
# 17018                                     NaN
# 17019                                     NaN
# 17020                                     NaN
# 17021                                     NaN
# ...                                       ...
# 3572287                                   0.0
# 3572288                                   0.0
# 3572289                                   0.0
# 3572290                                   0.0
# 3572291                                   0.0
#
#          M_WEATHER_FORECAST_SAMPLES_M_TRACK_TEMPERATURE  \
# 17017                                               NaN
# 17018                                               NaN
# 17019                                               NaN
# 17020                                               NaN
# 17021                                               NaN
# ...                                                 ...
# 3572287                                            33.0
# 3572288                                            33.0
# 3572289                                            33.0
# 3572290                                            33.0
# 3572291                                            32.0
#
#          M_TRACK_TEMPERATURE_CHANGE  \
# 17017                           NaN
# 17018                           NaN
# 17019                           NaN
# 17020                           NaN
# 17021                           NaN
# ...                             ...
# 3572287                         2.0
# 3572288                         2.0
# 3572289                         2.0
# 3572290                         2.0
# 3572291                         1.0
#
#          M_WEATHER_FORECAST_SAMPLES_M_AIR_TEMPERATURE  \
# 17017                                             NaN
# 17018                                             NaN
# 17019                                             NaN
# 17020                                             NaN
# 17021                                             NaN
# ...                                               ...
# 3572287                                          25.0
# 3572288                                          25.0
# 3572289                                          25.0
# 3572290                                          25.0
# 3572291                                          25.0
#
#          M_AIR_TEMPERATURE_CHANGE  M_RAIN_PERCENTAGE  M_WEATHER  \
# 17017                         NaN                NaN          0
# 17018                         NaN                NaN          0
# 17019                         NaN                NaN          0
# 17020                         NaN                NaN          0
# 17021                         NaN                NaN          0
# ...                           ...                ...        ...
# 3572287                       2.0                3.0          0
# 3572288                       2.0                3.0          0
# 3572289                       2.0                3.0          0
# 3572290                       2.0                3.0          0
# 3572291                       2.0                3.0          0
#
#          M_AI_DIFFICULTY
# 17017                 31
# 17018                 31
# 17019                 31
# 17020                 31
# 17021                 31
# ...                  ...
# 3572287              110
# 3572288              110
# 3572289              110
# 3572290              110
# 3572291              110
#
# [1393074 rows x 11 columns]

# %%
from sklearn import preprocessing

x = df_subset.drop(['M_WEATHER', 'TIMESTAMP'], axis=1).values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)

df_norm = pd.DataFrame(x_scaled, columns=df_subset.drop(['M_WEATHER', 'TIMESTAMP'], axis=1).columns.tolist())
df_norm['TIMESTAMP'] = pd.to_datetime(df_subset['TIMESTAMP'], unit='s', dayfirst=True).reset_index(drop=True)
df_norm['M_WEATHER'] = df_subset['M_WEATHER'].reset_index(drop=True)
df_norm = df_norm.set_index('TIMESTAMP')
df_norm
# Out:
#                      M_AIR_TEMPERATURE  M_TIME_OFFSET  \
# TIMESTAMP
# 2022-01-21 00:16:50           0.666667            NaN
# 2022-01-21 00:16:50           0.666667            NaN
# 2022-01-21 00:16:50           0.666667            NaN
# 2022-01-21 00:16:50           0.666667            NaN
# 2022-01-21 00:16:50           0.666667            NaN
# ...                                ...            ...
# 2022-01-15 23:14:51           0.666667       0.083333
# 2022-01-15 23:14:51           0.666667       0.125000
# 2022-01-15 23:14:51           0.666667       0.250000
# 2022-01-15 23:14:51           0.666667       0.375000
# 2022-01-15 23:14:51           0.666667       0.500000
#
#                      M_WEATHER_FORECAST_SAMPLES_M_WEATHER  \
# TIMESTAMP
# 2022-01-21 00:16:50                                   NaN
# 2022-01-21 00:16:50                                   NaN
# 2022-01-21 00:16:50                                   NaN
# 2022-01-21 00:16:50                                   NaN
# 2022-01-21 00:16:50                                   NaN
# ...                                                   ...
# 2022-01-15 23:14:51                                   0.0
# 2022-01-15 23:14:51                                   0.0
# 2022-01-15 23:14:51                                   0.0
# 2022-01-15 23:14:51                                   0.0
# 2022-01-15 23:14:51                                   0.0
#
#                      M_WEATHER_FORECAST_SAMPLES_M_TRACK_TEMPERATURE  \
# TIMESTAMP
# 2022-01-21 00:16:50                                             NaN
# 2022-01-21 00:16:50                                             NaN
# 2022-01-21 00:16:50                                             NaN
# 2022-01-21 00:16:50                                             NaN
# 2022-01-21 00:16:50                                             NaN
# ...                                                             ...
# 2022-01-15 23:14:51                                          0.8125
# 2022-01-15 23:14:51                                          0.8125
# 2022-01-15 23:14:51                                          0.8125
# 2022-01-15 23:14:51                                          0.8125
# 2022-01-15 23:14:51                                          0.7500
#
#                      M_TRACK_TEMPERATURE_CHANGE  \
# TIMESTAMP
# 2022-01-21 00:16:50                         NaN
# 2022-01-21 00:16:50                         NaN
# 2022-01-21 00:16:50                         NaN
# 2022-01-21 00:16:50                         NaN
# 2022-01-21 00:16:50                         NaN
# ...                                         ...
# 2022-01-15 23:14:51                         1.0
# 2022-01-15 23:14:51                         1.0
# 2022-01-15 23:14:51                         1.0
# 2022-01-15 23:14:51                         1.0
# 2022-01-15 23:14:51                         0.5
#
#                      M_WEATHER_FORECAST_SAMPLES_M_AIR_TEMPERATURE  \
# TIMESTAMP
# 2022-01-21 00:16:50                                           NaN
# 2022-01-21 00:16:50                                           NaN
# 2022-01-21 00:16:50                                           NaN
# 2022-01-21 00:16:50                                           NaN
# 2022-01-21 00:16:50                                           NaN
# ...                                                           ...
# 2022-01-15 23:14:51                                      0.666667
# 2022-01-15 23:14:51                                      0.666667
# 2022-01-15 23:14:51                                      0.666667
# 2022-01-15 23:14:51                                      0.666667
# 2022-01-15 23:14:51                                      0.666667
#
#                      M_AIR_TEMPERATURE_CHANGE  M_RAIN_PERCENTAGE  \
# TIMESTAMP
# 2022-01-21 00:16:50                       NaN                NaN
# 2022-01-21 00:16:50                       NaN                NaN
# 2022-01-21 00:16:50                       NaN                NaN
# 2022-01-21 00:16:50                       NaN                NaN
# 2022-01-21 00:16:50                       NaN                NaN
# ...                                       ...                ...
# 2022-01-15 23:14:51                       1.0           0.021739
# 2022-01-15 23:14:51                       1.0           0.021739
# 2022-01-15 23:14:51                       1.0           0.021739
# 2022-01-15 23:14:51                       1.0           0.021739
# 2022-01-15 23:14:51                       1.0           0.021739
#
#                      M_AI_DIFFICULTY  M_WEATHER
# TIMESTAMP
# 2022-01-21 00:16:50              0.0          0
# 2022-01-21 00:16:50              0.0          0
# 2022-01-21 00:16:50              0.0          0
# 2022-01-21 00:16:50              0.0          0
# 2022-01-21 00:16:50              0.0          0
# ...                              ...        ...
# 2022-01-15 23:14:51              1.0          0
# 2022-01-15 23:14:51              1.0          0
# 2022-01-15 23:14:51              1.0          0
# 2022-01-15 23:14:51              1.0          0
# 2022-01-15 23:14:51              1.0          0
#
# [1393074 rows x 10 columns]

# %%
df_norm['M_WEATHER'] = df_norm['M_WEATHER'].apply(lambda x: str(x))
df_norm
# Out:
#                      M_AIR_TEMPERATURE  M_TIME_OFFSET  \
# TIMESTAMP
# 2022-01-21 00:16:50           0.666667            NaN
# 2022-01-21 00:16:50           0.666667            NaN
# 2022-01-21 00:16:50           0.666667            NaN
# 2022-01-21 00:16:50           0.666667            NaN
# 2022-01-21 00:16:50           0.666667            NaN
# ...                                ...            ...
# 2022-01-15 23:14:51           0.666667       0.083333
# 2022-01-15 23:14:51           0.666667       0.125000
# 2022-01-15 23:14:51           0.666667       0.250000
# 2022-01-15 23:14:51           0.666667       0.375000
# 2022-01-15 23:14:51           0.666667       0.500000
#
#                      M_WEATHER_FORECAST_SAMPLES_M_WEATHER  \
# TIMESTAMP
# 2022-01-21 00:16:50                                   NaN
# 2022-01-21 00:16:50                                   NaN
# 2022-01-21 00:16:50                                   NaN
# 2022-01-21 00:16:50                                   NaN
# 2022-01-21 00:16:50                                   NaN
# ...                                                   ...
# 2022-01-15 23:14:51                                   0.0
# 2022-01-15 23:14:51                                   0.0
# 2022-01-15 23:14:51                                   0.0
# 2022-01-15 23:14:51                                   0.0
# 2022-01-15 23:14:51                                   0.0
#
#                      M_WEATHER_FORECAST_SAMPLES_M_TRACK_TEMPERATURE  \
# TIMESTAMP
# 2022-01-21 00:16:50                                             NaN
# 2022-01-21 00:16:50                                             NaN
# 2022-01-21 00:16:50                                             NaN
# 2022-01-21 00:16:50                                             NaN
# 2022-01-21 00:16:50                                             NaN
# ...                                                             ...
# 2022-01-15 23:14:51                                          0.8125
# 2022-01-15 23:14:51                                          0.8125
# 2022-01-15 23:14:51                                          0.8125
# 2022-01-15 23:14:51                                          0.8125
# 2022-01-15 23:14:51                                          0.7500
#
#                      M_TRACK_TEMPERATURE_CHANGE  \
# TIMESTAMP
# 2022-01-21 00:16:50                         NaN
# 2022-01-21 00:16:50                         NaN
# 2022-01-21 00:16:50                         NaN
# 2022-01-21 00:16:50                         NaN
# 2022-01-21 00:16:50                         NaN
# ...                                         ...
# 2022-01-15 23:14:51                         1.0
# 2022-01-15 23:14:51                         1.0
# 2022-01-15 23:14:51                         1.0
# 2022-01-15 23:14:51                         1.0
# 2022-01-15 23:14:51                         0.5
#
#                      M_WEATHER_FORECAST_SAMPLES_M_AIR_TEMPERATURE  \
# TIMESTAMP
# 2022-01-21 00:16:50                                           NaN
# 2022-01-21 00:16:50                                           NaN
# 2022-01-21 00:16:50                                           NaN
# 2022-01-21 00:16:50                                           NaN
# 2022-01-21 00:16:50                                           NaN
# ...                                                           ...
# 2022-01-15 23:14:51                                      0.666667
# 2022-01-15 23:14:51                                      0.666667
# 2022-01-15 23:14:51                                      0.666667
# 2022-01-15 23:14:51                                      0.666667
# 2022-01-15 23:14:51                                      0.666667
#
#                      M_AIR_TEMPERATURE_CHANGE  M_RAIN_PERCENTAGE  \
# TIMESTAMP
# 2022-01-21 00:16:50                       NaN                NaN
# 2022-01-21 00:16:50                       NaN                NaN
# 2022-01-21 00:16:50                       NaN                NaN
# 2022-01-21 00:16:50                       NaN                NaN
# 2022-01-21 00:16:50                       NaN                NaN
# ...                                       ...                ...
# 2022-01-15 23:14:51                       1.0           0.021739
# 2022-01-15 23:14:51                       1.0           0.021739
# 2022-01-15 23:14:51                       1.0           0.021739
# 2022-01-15 23:14:51                       1.0           0.021739
# 2022-01-15 23:14:51                       1.0           0.021739
#
#                      M_AI_DIFFICULTY M_WEATHER
# TIMESTAMP
# 2022-01-21 00:16:50              0.0         0
# 2022-01-21 00:16:50              0.0         0
# 2022-01-21 00:16:50              0.0         0
# 2022-01-21 00:16:50              0.0         0
# 2022-01-21 00:16:50              0.0         0
# ...                              ...       ...
# 2022-01-15 23:14:51              1.0         0
# 2022-01-15 23:14:51              1.0         0
# 2022-01-15 23:14:51              1.0         0
# 2022-01-15 23:14:51              1.0         0
# 2022-01-15 23:14:51              1.0         0
#
# [1393074 rows x 10 columns]

# %%
df_norm.dropna(inplace=True)

# %%
df = df_norm
Y = df['M_RAIN_PERCENTAGE']
X = df.drop(columns=['M_RAIN_PERCENTAGE'],inplace=False)

# %%
from sklearn.model_selection import train_test_split
X, X_test, y, y_test = train_test_split(X,Y,test_size = 0.2,train_size = 0.8,random_state = 42)
X_train, X_cv, y_train, y_cv = train_test_split(X,y,test_size = 0.25,train_size = 0.75,random_state = 42)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 10, random_state = 0)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
from numpy import mean
from numpy import std
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
cv = KFold(n_splits=10, random_state=1, shuffle=True)
n_scores = cross_val_score(model, X_cv, y_cv, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
# report performance
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: -0.002 (0.000)

# %%
from sklearn.metrics import mean_squared_error
predictions = model.predict(X_test)
MSE = mean_squared_error(y_test,predictions)
print(MSE)
# Out:
# 2.2057835662498397e-05

# %%
row = X.iloc[1].to_numpy().reshape(1,-1)
yhat = model.predict(row)
print('predicted rain probability is',yhat)
# Out:
# predicted rain probability is [0.02121813]
# /Users/home/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
filename = "finalized_randomforest_regressor_model.sav"
pickle.dump(model, (open(filename, "wb")))
